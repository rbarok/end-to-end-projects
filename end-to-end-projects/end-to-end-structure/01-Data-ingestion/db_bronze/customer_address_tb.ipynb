# %%
# %sql
SELECT * FROM end_to_end_retail.db_landing.customer_address where customer_id is not null 
limit 5

# %%
# %sql
SELECT * FROM end_to_end_retail.db_landing.customer_geoloc where customer_id is not null 
limit 5

# %%
# %sql
SELECT * FROM end_to_end_retail.db_landing.customer_taxid where customer_id is not null 
limit 5

# %%
# %sql
SELECT * FROM end_to_end_retail.db_landing.sales where customer_id is not null 
limit 5

# %%
# %sql
SELECT * FROM end_to_end_retail.db_landing.clicked_items where customer_id is not null 
limit 5
