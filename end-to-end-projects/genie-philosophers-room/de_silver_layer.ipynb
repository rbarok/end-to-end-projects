# %% [markdown]
# - At the silver layer table can be used by Genie, or any other RAG architecture.

# %%
# %sql
SELECT * FROM end_to_end_genie_room.db_silver.silver_philosophers_clean limit 5

# %% [markdown]
# - Silver layer should be used to create context in the dataset, also integrate different datasets to create gold layer;
