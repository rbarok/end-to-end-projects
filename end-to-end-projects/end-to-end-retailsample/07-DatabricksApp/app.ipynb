# %% [markdown]
# ### Databricks APPs
#
# - Genie Space: RAG tailored spaces, table metadata, table tags, table description, data model relationships beyond primary & foreign keys, sql-queries for cached context;
# - Custom Apps; Backend NodeJs; Frontend React, Gradio, Streamlit, etc.

# %% [markdown]
# - https://www.databricks.com/blog/present-and-share-notebook-results-in-aibi-dashboards
# - https://www.databricks.com/blog/how-build-production-ready-data-and-ai-apps-databricks-apps-and-lakebase
